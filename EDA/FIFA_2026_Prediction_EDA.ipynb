# %%
#FIFA Prediction 2026_ Project
#let's do some EDA

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("FIFA_2015 to 2026_Cleaned and Organised Data.csv")

# %%
df.head()
# Out:
#    Match_ID        Date      Competition  Home_Team Away_Team  Home_Rank  \
# 0         1  02-01-2015  Continental Cup    Morocco    Sweden         30
# 1         2  03-01-2015        World Cup     Poland       USA         19
# 2         3  04-01-2015   Nations League     Mexico    Canada         27
# 3         4  05-01-2015   Nations League     Poland    Canada         13
# 4         5  06-01-2015   Nations League  Argentina    Sweden         22
#
#    Away_Rank  Home_Elo  Away_Elo  Home_Goals  ...  Rank Difference      Teams  \
# 0          7      2160      2171           3  ...               23    Morocco
# 1         10      2034      2157           3  ...                9     Poland
# 2         24      2179      2165           3  ...                3     Mexico
# 3         23      2058      2008           4  ...              -10  Argentina
# 4         30      2184      1866           1  ...               -8    Germany
#
#    Total Match Played  Total Win  Win %  Trim Home_TEAM  Trim Away_TEAM  \
# 0                74.0       31.0  41.89         Morocco          Sweden
# 1                70.0       24.0  34.29          Poland             USA
# 2                63.0       30.0  47.62          Mexico          Canada
# 3                67.0       32.0  47.76          Poland          Canada
# 4                68.0       23.0  33.82       Argentina          Sweden
#
#    Unnamed: 30  Unnamed: 31                      Unnamed: 32
# 0      Morocco          NaN  // -ve means home team stronger
# 1       Poland          NaN  // +ve means away team stronger
# 2       Mexico          NaN                              NaN
# 3    Argentina          NaN                              NaN
# 4      Germany          NaN                              NaN
#
# [5 rows x 33 columns]

# %%
df
# Out:
#      Match_ID        Date      Competition  Home_Team  Away_Team  Home_Rank  \
# 0           1  02-01-2015  Continental Cup    Morocco     Sweden         30
# 1           2  03-01-2015        World Cup     Poland        USA         19
# 2           3  04-01-2015   Nations League     Mexico     Canada         27
# 3           4  05-01-2015   Nations League     Poland     Canada         13
# 4           5  06-01-2015   Nations League  Argentina     Sweden         22
# ..        ...         ...              ...        ...        ...        ...
# 995       996  23-09-2017        World Cup     France    Morocco          2
# 996       997  24-09-2017   Nations League   Portugal     Norway         26
# 997       998  25-09-2017     WC Qualifier   Portugal    England          2
# 998       999  26-09-2017     WC Qualifier    Denmark  Argentina         28
# 999      1000  27-09-2017     WC Qualifier     Turkey     France         12
#
#      Away_Rank  Home_Elo  Away_Elo  Home_Goals  ...  Rank Difference  \
# 0            7      2160      2171           3  ...               23
# 1           10      2034      2157           3  ...                9
# 2           24      2179      2165           3  ...                3
# 3           23      2058      2008           4  ...              -10
# 4           30      2184      1866           1  ...               -8
# ..         ...       ...       ...         ...  ...              ...
# 995         29      2185      2144           5  ...              -27
# 996         27      1853      2079           0  ...               -1
# 997         24      1872      1862           3  ...              -22
# 998         15      1957      2068           0  ...               13
# 999         10      1764      2024           4  ...                2
#
#          Teams  Total Match Played  Total Win  Win %  Trim Home_TEAM  \
# 0      Morocco                74.0       31.0  41.89         Morocco
# 1       Poland                70.0       24.0  34.29          Poland
# 2       Mexico                63.0       30.0  47.62          Mexico
# 3    Argentina                67.0       32.0  47.76          Poland
# 4      Germany                68.0       23.0  33.82       Argentina
# ..         ...                 ...        ...    ...             ...
# 995        NaN                 NaN        NaN    NaN          France
# 996        NaN                 NaN        NaN    NaN        Portugal
# 997        NaN                 NaN        NaN    NaN        Portugal
# 998        NaN                 NaN        NaN    NaN         Denmark
# 999        NaN                 NaN        NaN    NaN          Turkey
#
#      Trim Away_TEAM  Unnamed: 30  Unnamed: 31                      Unnamed: 32
# 0            Sweden      Morocco          NaN  // -ve means home team stronger
# 1               USA       Poland          NaN  // +ve means away team stronger
# 2            Canada       Mexico          NaN                              NaN
# 3            Canada    Argentina          NaN                              NaN
# 4            Sweden      Germany          NaN                              NaN
# ..              ...          ...          ...                              ...
# 995         Morocco          NaN          NaN                              NaN
# 996          Norway          NaN          NaN                              NaN
# 997         England          NaN          NaN                              NaN
# 998       Argentina          NaN          NaN                              NaN
# 999          France          NaN          NaN                              NaN
#
# [1000 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Match_ID             1000 non-null   int64
#  1   Date                 1000 non-null   object
#  2   Competition          1000 non-null   object
#  3   Home_Team            1000 non-null   object
#  4   Away_Team            1000 non-null   object
#  5   Home_Rank            1000 non-null   int64
#  6   Away_Rank            1000 non-null   int64
#  7   Home_Elo             1000 non-null   int64
#  8   Away_Elo             1000 non-null   int64
#  9   Home_Goals           1000 non-null   int64
#  10  Away_Goals           1000 non-null   int64
#  11  Goal_Diff            1000 non-null   int64
#  12  Home_Form            1000 non-null   float64
#  13  Away_Form            1000 non-null   float64
#  14  Home_Win_Pct         1000 non-null   int64
#  15  Away_Win_Pct         1000 non-null   int64
#  16  Clean_Sheet_Pct      1000 non-null   int64
#  17  Host_Advantage       1000 non-null   int64
#  18  Continent_Advantage  1000 non-null   int64
#  19  Result               1000 non-null   object
#  20  Year                 1000 non-null   int64
#  21  Month                1000 non-null   int64
#  22  Total Goals          1000 non-null   int64
#  23  Rank Difference      1000 non-null   int64
#  24  Teams                30 non-null     object
#  25  Total Match Played   30 non-null     float64
#  26  Total Win            30 non-null     float64
#  27  Win %                30 non-null     float64
#  28  Trim Home_TEAM       1000 non-null   object
#  29  Trim Away_TEAM       1000 non-null   object
#  30  Unnamed: 30          30 non-null     object
#  31  Unnamed: 31          0 non-null      float64
#  32  Unnamed: 32          2 non-null      object
# dtypes: float64(6), int64(17), object(10)
# memory usage: 257.9+ KB

# %%
df.isnull().sum()
# Out:
# Match_ID                  0
# Date                      0
# Competition               0
# Home_Team                 0
# Away_Team                 0
# Home_Rank                 0
# Away_Rank                 0
# Home_Elo                  0
# Away_Elo                  0
# Home_Goals                0
# Away_Goals                0
# Goal_Diff                 0
# Home_Form                 0
# Away_Form                 0
# Home_Win_Pct              0
# Away_Win_Pct              0
# Clean_Sheet_Pct           0
# Host_Advantage            0
# Continent_Advantage       0
# Result                    0
# Year                      0
# Month                     0
# Total Goals               0
# Rank Difference           0
# Teams                   970
# Total Match Played      970
# Total Win               970
# Win %                   970
# Trim Home_TEAM            0
# Trim Away_TEAM            0
# Unnamed: 30             970
# Unnamed: 31            1000
# Unnamed: 32             998
# dtype: int64

# %%
df = df.drop(['Trim Home_TEAM', 'Trim Away_TEAM','Unnamed: 30','Unnamed: 31','Unnamed: 32'], axis=1)

# %%
df
# Out:
#      Match_ID        Date      Competition  Home_Team  Away_Team  Home_Rank  \
# 0           1  02-01-2015  Continental Cup    Morocco     Sweden         30
# 1           2  03-01-2015        World Cup     Poland        USA         19
# 2           3  04-01-2015   Nations League     Mexico     Canada         27
# 3           4  05-01-2015   Nations League     Poland     Canada         13
# 4           5  06-01-2015   Nations League  Argentina     Sweden         22
# ..        ...         ...              ...        ...        ...        ...
# 995       996  23-09-2017        World Cup     France    Morocco          2
# 996       997  24-09-2017   Nations League   Portugal     Norway         26
# 997       998  25-09-2017     WC Qualifier   Portugal    England          2
# 998       999  26-09-2017     WC Qualifier    Denmark  Argentina         28
# 999      1000  27-09-2017     WC Qualifier     Turkey     France         12
#
#      Away_Rank  Home_Elo  Away_Elo  Home_Goals  ...  Continent_Advantage  \
# 0            7      2160      2171           3  ...                    1
# 1           10      2034      2157           3  ...                    1
# 2           24      2179      2165           3  ...                    1
# 3           23      2058      2008           4  ...                    1
# 4           30      2184      1866           1  ...                    0
# ..         ...       ...       ...         ...  ...                  ...
# 995         29      2185      2144           5  ...                    1
# 996         27      1853      2079           0  ...                    1
# 997         24      1872      1862           3  ...                    0
# 998         15      1957      2068           0  ...                    1
# 999         10      1764      2024           4  ...                    1
#
#        Result  Year  Month  Total Goals  Rank Difference      Teams  \
# 0    Home Win  2015      1            3               23    Morocco
# 1    Home Win  2015      1            5                9     Poland
# 2    Away Win  2015      1            8                3     Mexico
# 3    Away Win  2015      1            9              -10  Argentina
# 4    Away Win  2015      1            3               -8    Germany
# ..        ...   ...    ...          ...              ...        ...
# 995  Home Win  2017      9            6              -27        NaN
# 996  Away Win  2017      9            3               -1        NaN
# 997  Home Win  2017      9            4              -22        NaN
# 998  Away Win  2017      9            5               13        NaN
# 999      Draw  2017      9            8                2        NaN
#
#      Total Match Played  Total Win  Win %
# 0                  74.0       31.0  41.89
# 1                  70.0       24.0  34.29
# 2                  63.0       30.0  47.62
# 3                  67.0       32.0  47.76
# 4                  68.0       23.0  33.82
# ..                  ...        ...    ...
# 995                 NaN        NaN    NaN
# 996                 NaN        NaN    NaN
# 997                 NaN        NaN    NaN
# 998                 NaN        NaN    NaN
# 999                 NaN        NaN    NaN
#
# [1000 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# Match_ID                 0
# Date                     0
# Competition              0
# Home_Team                0
# Away_Team                0
# Home_Rank                0
# Away_Rank                0
# Home_Elo                 0
# Away_Elo                 0
# Home_Goals               0
# Away_Goals               0
# Goal_Diff                0
# Home_Form                0
# Away_Form                0
# Home_Win_Pct             0
# Away_Win_Pct             0
# Clean_Sheet_Pct          0
# Host_Advantage           0
# Continent_Advantage      0
# Result                   0
# Year                     0
# Month                    0
# Total Goals              0
# Rank Difference          0
# Teams                  970
# Total Match Played     970
# Total Win              970
# Win %                  970
# dtype: int64

# %%
df = df.drop(columns=[
    'Teams',
    'Total Match Played',
    'Total Win',
    'Win %'
])

# %%
df
# Out:
#      Match_ID        Date      Competition  Home_Team  Away_Team  Home_Rank  \
# 0           1  02-01-2015  Continental Cup    Morocco     Sweden         30
# 1           2  03-01-2015        World Cup     Poland        USA         19
# 2           3  04-01-2015   Nations League     Mexico     Canada         27
# 3           4  05-01-2015   Nations League     Poland     Canada         13
# 4           5  06-01-2015   Nations League  Argentina     Sweden         22
# ..        ...         ...              ...        ...        ...        ...
# 995       996  23-09-2017        World Cup     France    Morocco          2
# 996       997  24-09-2017   Nations League   Portugal     Norway         26
# 997       998  25-09-2017     WC Qualifier   Portugal    England          2
# 998       999  26-09-2017     WC Qualifier    Denmark  Argentina         28
# 999      1000  27-09-2017     WC Qualifier     Turkey     France         12
#
#      Away_Rank  Home_Elo  Away_Elo  Home_Goals  ...  Home_Win_Pct  \
# 0            7      2160      2171           3  ...            42
# 1           10      2034      2157           3  ...            52
# 2           24      2179      2165           3  ...            45
# 3           23      2058      2008           4  ...            68
# 4           30      2184      1866           1  ...            58
# ..         ...       ...       ...         ...  ...           ...
# 995         29      2185      2144           5  ...            56
# 996         27      1853      2079           0  ...            54
# 997         24      1872      1862           3  ...            73
# 998         15      1957      2068           0  ...            68
# 999         10      1764      2024           4  ...            45
#
#      Away_Win_Pct  Clean_Sheet_Pct  Host_Advantage  Continent_Advantage  \
# 0              41               41               1                    1
# 1              40               38               0                    1
# 2              77               27               0                    1
# 3              56               48               1                    1
# 4              80               52               0                    0
# ..            ...              ...             ...                  ...
# 995            44               63               1                    1
# 996            69               49               0                    1
# 997            80               46               1                    0
# 998            63               52               0                    1
# 999            46               46               1                    1
#
#        Result  Year  Month  Total Goals Rank Difference
# 0    Home Win  2015      1            3              23
# 1    Home Win  2015      1            5               9
# 2    Away Win  2015      1            8               3
# 3    Away Win  2015      1            9             -10
# 4    Away Win  2015      1            3              -8
# ..        ...   ...    ...          ...             ...
# 995  Home Win  2017      9            6             -27
# 996  Away Win  2017      9            3              -1
# 997  Home Win  2017      9            4             -22
# 998  Away Win  2017      9            5              13
# 999      Draw  2017      9            8               2
#
# [1000 rows x 24 columns]

# %%
#we are finding unique team on the basis of Home_Team , Away_Team
home_team = df['Home_Team'].unique()
away_team = df['Away_Team'].unique()
all_teams = set(home_team).union(set(away_team))
len(all_teams)
# Out:
# 30

# %%
sorted(all_teams)
# Out:
# ['Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Colombia',
#  'Croatia',
#  'Denmark',
#  'England',
#  'France',
#  'Germany',
#  'Italy',
#  'Japan',
#  'Mexico',
#  'Morocco',
#  'Netherlands',
#  'Nigeria',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Senegal',
#  'Serbia',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'USA',
#  'Uruguay']

# %%
#this convert list into table or you can say that converting into DataFrame
teams_df = pd.DataFrame(all_teams, columns=['Team'])
teams_df.head()
# Out:
#           Team
# 0       Serbia
# 1      Uruguay
# 2      Belgium
# 3  Netherlands
# 4        Italy

# %%
teams_df
# Out:
#            Team
# 0        Serbia
# 1       Uruguay
# 2       Belgium
# 3   Netherlands
# 4         Italy
# 5   Switzerland
# 6      Colombia
# 7       England
# 8     Argentina
# 9      Portugal
# 10      Senegal
# 11      Denmark
# 12      Austria
# 13  South Korea
# 14      Morocco
# 15      Croatia
# 16       Brazil
# 17       Poland
# 18       Canada
# 19       France
# 20       Norway
# 21       Mexico
# 22    Australia
# 23        Japan
# 24      Nigeria
# 25        Spain
# 26       Turkey
# 27          USA
# 28      Germany
# 29       Sweden

# %%
#how many matches each team played  -- combined home + away appearence

# %%
team_counts = pd.concat([
    df['Home_Team'],
    df['Away_Team']
]).value_counts()
#value_count -- counts how many times each team appears
team_counts
# Out:
# Senegal        85
# Japan          79
# Switzerland    79
# Portugal       77
# Morocco        74
# France         73
# Australia      72
# Poland         70
# Norway         69
# Croatia        69
# Germany        68
# Nigeria        68
# Netherlands    67
# Argentina      67
# Turkey         67
# Denmark        67
# England        66
# Serbia         65
# Belgium        64
# Brazil         64
# Sweden         64
# Austria        64
# Mexico         63
# Canada         63
# Uruguay        58
# Colombia       58
# Italy          57
# Spain          57
# South Korea    53
# USA            53
# Name: count, dtype: int64

# %% [markdown]
# The african champion (AFCON)  SENEGAL play the most international match from 2015 to 2026

# %%
#Top 10 most played teams

# %%
team_counts.head(10)
# Out:
# Senegal        85
# Japan          79
# Switzerland    79
# Portugal       77
# Morocco        74
# France         73
# Australia      72
# Poland         70
# Norway         69
# Croatia        69
# Name: count, dtype: int64

# %%
team_counts.head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
df
# Out:
#      Match_ID        Date      Competition  Home_Team  Away_Team  Home_Rank  \
# 0           1  02-01-2015  Continental Cup    Morocco     Sweden         30
# 1           2  03-01-2015        World Cup     Poland        USA         19
# 2           3  04-01-2015   Nations League     Mexico     Canada         27
# 3           4  05-01-2015   Nations League     Poland     Canada         13
# 4           5  06-01-2015   Nations League  Argentina     Sweden         22
# ..        ...         ...              ...        ...        ...        ...
# 995       996  23-09-2017        World Cup     France    Morocco          2
# 996       997  24-09-2017   Nations League   Portugal     Norway         26
# 997       998  25-09-2017     WC Qualifier   Portugal    England          2
# 998       999  26-09-2017     WC Qualifier    Denmark  Argentina         28
# 999      1000  27-09-2017     WC Qualifier     Turkey     France         12
#
#      Away_Rank  Home_Elo  Away_Elo  Home_Goals  ...  Home_Win_Pct  \
# 0            7      2160      2171           3  ...            42
# 1           10      2034      2157           3  ...            52
# 2           24      2179      2165           3  ...            45
# 3           23      2058      2008           4  ...            68
# 4           30      2184      1866           1  ...            58
# ..         ...       ...       ...         ...  ...           ...
# 995         29      2185      2144           5  ...            56
# 996         27      1853      2079           0  ...            54
# 997         24      1872      1862           3  ...            73
# 998         15      1957      2068           0  ...            68
# 999         10      1764      2024           4  ...            45
#
#      Away_Win_Pct  Clean_Sheet_Pct  Host_Advantage  Continent_Advantage  \
# 0              41               41               1                    1
# 1              40               38               0                    1
# 2              77               27               0                    1
# 3              56               48               1                    1
# 4              80               52               0                    0
# ..            ...              ...             ...                  ...
# 995            44               63               1                    1
# 996            69               49               0                    1
# 997            80               46               1                    0
# 998            63               52               0                    1
# 999            46               46               1                    1
#
#        Result  Year  Month  Total Goals Rank Difference
# 0    Home Win  2015      1            3              23
# 1    Home Win  2015      1            5               9
# 2    Away Win  2015      1            8               3
# 3    Away Win  2015      1            9             -10
# 4    Away Win  2015      1            3              -8
# ..        ...   ...    ...          ...             ...
# 995  Home Win  2017      9            6             -27
# 996  Away Win  2017      9            3              -1
# 997  Home Win  2017      9            4             -22
# 998  Away Win  2017      9            5              13
# 999      Draw  2017      9            8               2
#
# [1000 rows x 24 columns]

# %%
df
# Out:
#      Match_ID        Date      Competition  Home_Team  Away_Team  Home_Rank  \
# 0           1  02-01-2015  Continental Cup    Morocco     Sweden         30
# 1           2  03-01-2015        World Cup     Poland        USA         19
# 2           3  04-01-2015   Nations League     Mexico     Canada         27
# 3           4  05-01-2015   Nations League     Poland     Canada         13
# 4           5  06-01-2015   Nations League  Argentina     Sweden         22
# ..        ...         ...              ...        ...        ...        ...
# 995       996  23-09-2017        World Cup     France    Morocco          2
# 996       997  24-09-2017   Nations League   Portugal     Norway         26
# 997       998  25-09-2017     WC Qualifier   Portugal    England          2
# 998       999  26-09-2017     WC Qualifier    Denmark  Argentina         28
# 999      1000  27-09-2017     WC Qualifier     Turkey     France         12
#
#      Away_Rank  Home_Elo  Away_Elo  Home_Goals  ...  Home_Win_Pct  \
# 0            7      2160      2171           3  ...            42
# 1           10      2034      2157           3  ...            52
# 2           24      2179      2165           3  ...            45
# 3           23      2058      2008           4  ...            68
# 4           30      2184      1866           1  ...            58
# ..         ...       ...       ...         ...  ...           ...
# 995         29      2185      2144           5  ...            56
# 996         27      1853      2079           0  ...            54
# 997         24      1872      1862           3  ...            73
# 998         15      1957      2068           0  ...            68
# 999         10      1764      2024           4  ...            45
#
#      Away_Win_Pct  Clean_Sheet_Pct  Host_Advantage  Continent_Advantage  \
# 0              41               41               1                    1
# 1              40               38               0                    1
# 2              77               27               0                    1
# 3              56               48               1                    1
# 4              80               52               0                    0
# ..            ...              ...             ...                  ...
# 995            44               63               1                    1
# 996            69               49               0                    1
# 997            80               46               1                    0
# 998            63               52               0                    1
# 999            46               46               1                    1
#
#        Result  Year  Month  Total Goals Rank Difference
# 0    Home Win  2015      1            3              23
# 1    Home Win  2015      1            5               9
# 2    Away Win  2015      1            8               3
# 3    Away Win  2015      1            9             -10
# 4    Away Win  2015      1            3              -8
# ..        ...   ...    ...          ...             ...
# 995  Home Win  2017      9            6             -27
# 996  Away Win  2017      9            3              -1
# 997  Home Win  2017      9            4             -22
# 998  Away Win  2017      9            5              13
# 999      Draw  2017      9            8               2
#
# [1000 rows x 24 columns]

# %%
teams_df
# Out:
#            Team
# 0        Serbia
# 1       Uruguay
# 2       Belgium
# 3   Netherlands
# 4         Italy
# 5   Switzerland
# 6      Colombia
# 7       England
# 8     Argentina
# 9      Portugal
# 10      Senegal
# 11      Denmark
# 12      Austria
# 13  South Korea
# 14      Morocco
# 15      Croatia
# 16       Brazil
# 17       Poland
# 18       Canada
# 19       France
# 20       Norway
# 21       Mexico
# 22    Australia
# 23        Japan
# 24      Nigeria
# 25        Spain
# 26       Turkey
# 27          USA
# 28      Germany
# 29       Sweden

# %%
#Count wins per team

# %%
home_wins = df[df['Home_Goals'] > df['Away_Goals']]['Home_Team']
away_wins = df[df['Away_Goals'] > df['Home_Goals']]['Away_Team']

wins = pd.concat([home_wins, away_wins]).value_counts()

# %%
wins
# Out:
# Senegal        39
# Japan          38
# France         37
# Netherlands    36
# Nigeria        33
# Argentina      32
# Norway         32
# Brazil         32
# Sweden         31
# Morocco        31
# Mexico         30
# Switzerland    30
# Canada         30
# Denmark        29
# Portugal       28
# Croatia        28
# Belgium        27
# Australia      27
# Italy          25
# Uruguay        24
# England        24
# Poland         24
# Serbia         23
# Germany        23
# Spain          23
# South Korea    22
# Austria        22
# Turkey         22
# Colombia       20
# USA            16
# Name: count, dtype: int64

# %%
matches_played = pd.concat([
    df['Home_Team'],
    df['Away_Team']
]).value_counts()

# %%
matches_played
# Out:
# Senegal        85
# Japan          79
# Switzerland    79
# Portugal       77
# Morocco        74
# France         73
# Australia      72
# Poland         70
# Norway         69
# Croatia        69
# Germany        68
# Nigeria        68
# Netherlands    67
# Argentina      67
# Turkey         67
# Denmark        67
# England        66
# Serbia         65
# Belgium        64
# Brazil         64
# Sweden         64
# Austria        64
# Mexico         63
# Canada         63
# Uruguay        58
# Colombia       58
# Italy          57
# Spain          57
# South Korea    53
# USA            53
# Name: count, dtype: int64

# %%
#WIN % by each teams

# %%
win_percent = (wins / matches_played) * 100
win_percent = win_percent.fillna(0)

win_percent.head(15)
# Out:
# Argentina    47.761194
# Australia    37.500000
# Austria      34.375000
# Belgium      42.187500
# Brazil       50.000000
# Canada       47.619048
# Colombia     34.482759
# Croatia      40.579710
# Denmark      43.283582
# England      36.363636
# France       50.684932
# Germany      33.823529
# Italy        43.859649
# Japan        48.101266
# Mexico       47.619048
# Name: count, dtype: float64

# %%
#converting all into DATA Frame
win_df = pd.DataFrame({
    'Team': matches_played.index,
    'Matches_Played': matches_played.values,
    'Wins': matches_played.index.map(wins).fillna(0).values,
    'Win %': win_percent.values
})

win_df.head(15)
# Out:
#            Team  Matches_Played  Wins      Win %
# 0       Senegal              85    39  47.761194
# 1         Japan              79    38  37.500000
# 2   Switzerland              79    30  34.375000
# 3      Portugal              77    28  42.187500
# 4       Morocco              74    31  50.000000
# 5        France              73    37  47.619048
# 6     Australia              72    27  34.482759
# 7        Poland              70    24  40.579710
# 8        Norway              69    32  43.283582
# 9       Croatia              69    28  36.363636
# 10      Germany              68    23  50.684932
# 11      Nigeria              68    33  33.823529
# 12  Netherlands              67    36  43.859649
# 13    Argentina              67    32  48.101266
# 14       Turkey              67    22  47.619048

# %%
#Top 10 Teams by Win%

# %%
win_df.sort_values('Win %', ascending=False).head(10)
# Out:
#          Team  Matches_Played  Wins      Win %
# 16    England              66    24  53.731343
# 10    Germany              68    23  50.684932
# 4     Morocco              74    31  50.000000
# 17     Serbia              65    23  48.529412
# 25   Colombia              58    20  48.437500
# 13  Argentina              67    32  48.101266
# 0     Senegal              85    39  47.761194
# 14     Turkey              67    22  47.619048
# 5      France              73    37  47.619048
# 18    Belgium              64    27  46.376812

# %%
win_df
# Out:
#            Team  Matches_Played  Wins      Win %
# 0       Senegal              85    39  47.761194
# 1         Japan              79    38  37.500000
# 2   Switzerland              79    30  34.375000
# 3      Portugal              77    28  42.187500
# 4       Morocco              74    31  50.000000
# 5        France              73    37  47.619048
# 6     Australia              72    27  34.482759
# 7        Poland              70    24  40.579710
# 8        Norway              69    32  43.283582
# 9       Croatia              69    28  36.363636
# 10      Germany              68    23  50.684932
# 11      Nigeria              68    33  33.823529
# 12  Netherlands              67    36  43.859649
# 13    Argentina              67    32  48.101266
# 14       Turkey              67    22  47.619048
# 15      Denmark              67    29  41.891892
# 16      England              66    24  53.731343
# 17       Serbia              65    23  48.529412
# 18      Belgium              64    27  46.376812
# 19       Brazil              64    32  34.285714
# 20       Sweden              64    31  36.363636
# 21      Austria              64    22  45.882353
# 22       Mexico              63    30  35.384615
# 23       Canada              63    30  41.509434
# 24      Uruguay              58    24  40.350877
# 25     Colombia              58    20  48.437500
# 26        Italy              57    25  37.974684
# 27        Spain              57    23  32.835821
# 28  South Korea              53    22  30.188679
# 29          USA              53    16  41.379310

# %%
all_teams
# Out:
# {'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Colombia',
#  'Croatia',
#  'Denmark',
#  'England',
#  'France',
#  'Germany',
#  'Italy',
#  'Japan',
#  'Mexico',
#  'Morocco',
#  'Netherlands',
#  'Nigeria',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Senegal',
#  'Serbia',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'USA',
#  'Uruguay'}

# %%
teams_df
# Out:
#            Team
# 0        Serbia
# 1       Uruguay
# 2       Belgium
# 3   Netherlands
# 4         Italy
# 5   Switzerland
# 6      Colombia
# 7       England
# 8     Argentina
# 9      Portugal
# 10      Senegal
# 11      Denmark
# 12      Austria
# 13  South Korea
# 14      Morocco
# 15      Croatia
# 16       Brazil
# 17       Poland
# 18       Canada
# 19       France
# 20       Norway
# 21       Mexico
# 22    Australia
# 23        Japan
# 24      Nigeria
# 25        Spain
# 26       Turkey
# 27          USA
# 28      Germany
# 29       Sweden

# %%
df
# Out:
#      Match_ID        Date      Competition  Home_Team  Away_Team  Home_Rank  \
# 0           1  02-01-2015  Continental Cup    Morocco     Sweden         30
# 1           2  03-01-2015        World Cup     Poland        USA         19
# 2           3  04-01-2015   Nations League     Mexico     Canada         27
# 3           4  05-01-2015   Nations League     Poland     Canada         13
# 4           5  06-01-2015   Nations League  Argentina     Sweden         22
# ..        ...         ...              ...        ...        ...        ...
# 995       996  23-09-2017        World Cup     France    Morocco          2
# 996       997  24-09-2017   Nations League   Portugal     Norway         26
# 997       998  25-09-2017     WC Qualifier   Portugal    England          2
# 998       999  26-09-2017     WC Qualifier    Denmark  Argentina         28
# 999      1000  27-09-2017     WC Qualifier     Turkey     France         12
#
#      Away_Rank  Home_Elo  Away_Elo  Home_Goals  ...  Home_Win_Pct  \
# 0            7      2160      2171           3  ...            42
# 1           10      2034      2157           3  ...            52
# 2           24      2179      2165           3  ...            45
# 3           23      2058      2008           4  ...            68
# 4           30      2184      1866           1  ...            58
# ..         ...       ...       ...         ...  ...           ...
# 995         29      2185      2144           5  ...            56
# 996         27      1853      2079           0  ...            54
# 997         24      1872      1862           3  ...            73
# 998         15      1957      2068           0  ...            68
# 999         10      1764      2024           4  ...            45
#
#      Away_Win_Pct  Clean_Sheet_Pct  Host_Advantage  Continent_Advantage  \
# 0              41               41               1                    1
# 1              40               38               0                    1
# 2              77               27               0                    1
# 3              56               48               1                    1
# 4              80               52               0                    0
# ..            ...              ...             ...                  ...
# 995            44               63               1                    1
# 996            69               49               0                    1
# 997            80               46               1                    0
# 998            63               52               0                    1
# 999            46               46               1                    1
#
#        Result  Year  Month  Total Goals Rank Difference
# 0    Home Win  2015      1            3              23
# 1    Home Win  2015      1            5               9
# 2    Away Win  2015      1            8               3
# 3    Away Win  2015      1            9             -10
# 4    Away Win  2015      1            3              -8
# ..        ...   ...    ...          ...             ...
# 995  Home Win  2017      9            6             -27
# 996  Away Win  2017      9            3              -1
# 997  Home Win  2017      9            4             -22
# 998  Away Win  2017      9            5              13
# 999      Draw  2017      9            8               2
#
# [1000 rows x 24 columns]

# %% [markdown]
# ## **match results (Win/Loss/Draw)**

# %%
import numpy as np

df['Home_Win'] = df['Home_Goals'] > df['Away_Goals']
df['Away_Win'] = df['Away_Goals'] > df['Home_Goals']
df['Draw'] = df['Home_Goals'] == df['Away_Goals']

# %%
#Home_Stat

# %%
home = df.groupby('Home_Team').agg(
    Matches=('Home_Team', 'count'),
    Wins=('Home_Win', 'sum'),
    Goals=('Home_Goals', 'sum')
).reset_index()

home.columns = ['Team', 'Matches', 'Wins', 'Goals']

# %%
#Away_Stat

# %%
away =df.groupby('Away_Team').agg(
    Matches=('Away_Team', 'count'),
    Wins=('Away_Win', 'sum'),
    Goals=('Away_Goals', 'sum')
).reset_index()
away.columns = ['Team', 'Matches', 'Wins', 'Goals']

# %%
#Combine Both

# %%
team_stats = pd.concat([home, away]).groupby('Team').sum().reset_index()

# %%
team_stats
# Out:
#            Team  Matches  Wins  Goals
# 0     Argentina       67    32    184
# 1     Australia       72    27    184
# 2       Austria       64    22    140
# 3       Belgium       64    27    166
# 4        Brazil       64    32    192
# 5        Canada       63    30    161
# 6      Colombia       58    20    125
# 7       Croatia       69    28    174
# 8       Denmark       67    29    163
# 9       England       66    24    154
# 10       France       73    37    192
# 11      Germany       68    23    174
# 12        Italy       57    25    154
# 13        Japan       79    38    224
# 14       Mexico       63    30    168
# 15      Morocco       74    31    188
# 16  Netherlands       67    36    185
# 17      Nigeria       68    33    167
# 18       Norway       69    32    184
# 19       Poland       70    24    181
# 20     Portugal       77    28    167
# 21      Senegal       85    39    215
# 22       Serbia       65    23    174
# 23  South Korea       53    22    131
# 24        Spain       57    23    145
# 25       Sweden       64    31    164
# 26  Switzerland       79    30    223
# 27       Turkey       67    22    166
# 28          USA       53    16    123
# 29      Uruguay       58    24    149

# %%
team_stats['Win %'] = (team_stats['Wins'] / team_stats['Matches']) * 100

# %%
team_stats = team_stats.sort_values(by='Win %', ascending=False)
team_stats.head(10)
# Out:
#            Team  Matches  Wins  Goals      Win %
# 16  Netherlands       67    36    185  53.731343
# 10       France       73    37    192  50.684932
# 4        Brazil       64    32    192  50.000000
# 17      Nigeria       68    33    167  48.529412
# 25       Sweden       64    31    164  48.437500
# 13        Japan       79    38    224  48.101266
# 0     Argentina       67    32    184  47.761194
# 14       Mexico       63    30    168  47.619048
# 5        Canada       63    30    161  47.619048
# 18       Norway       69    32    184  46.376812

# %% [markdown]
# Let have some Graph Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=team_stats, x='Goals', y='Win %')
plt.title("Goals vs Win % Relationship")
plt.show()

# %%
top_goals = team_stats.sort_values('Goals', ascending=False).head(10)

plt.figure(figsize=(10,5))
sns.barplot(x='Goals', y='Team', data=top_goals)
plt.title("Top 10 Teams by Goals")
plt.show()

#TOP 10 TEAMS BY GOALS

# %%
top_wins = team_stats.sort_values('Wins', ascending=False).head(10)

plt.figure(figsize=(10,5))
sns.barplot(x='Wins', y='Team', data=top_wins)
plt.title("Top 10 Teams by Wins")
plt.show()

#top 10 Teams by Wins
